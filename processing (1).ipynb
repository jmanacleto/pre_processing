# %% [markdown]
# ### Importar as bibliotecas essenciais para álgebra linear e processamento de dados

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# ### Listar os arquivos presentes no diretório de entrada do Kaggle

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dadosTextosCientificos.tsv

# %% [markdown]
# ### Carregar o arquivo TSV com dados científicos em um DataFrame

# %%
df = pd.read_csv('/kaggle/input/dadosTextosCientificos.tsv',
                   sep='\t',
                   engine='python',
                   encoding='latin-1')

# %%
df
# Out:
#                                          Título_Público  \
# 0     Açúcar de frutas e aplicação em bolos como sub...
# 1     Desenvolver uma linha de farofas com castanhas...
# 2     Desenvolvimento de cobertura líquida para sorvete
# 3          Desenvolvimento de conserva de tomate cereja
# 4     Desenvolvimento de massa alimentícia enriqueci...
# ...                                                 ...
# 2720  Desenvolvimento de ativos biotecnológicos para...
# 2721                                      SIMA MV POWER
# 2722                           Talhonameno Ótimo Klabin
# 2723  Tecnologia de Quantificação de Estoque de Carb...
# 2724  Desenvolvimento de Plataforma Digital de Bioi...
#
#                                       Descricao_pública
# 0     O uso de inovações tecnológicas auxilia as ind...
# 1     O uso de inovações tecnológicas auxilia as ind...
# 2     O Brasil é considerado um país com a maior bio...
# 3     O Brasil é considerado o país com maior biodiv...
# 4     Nos últimos anos a comunidade científica tem d...
# ...                                                 ...
# 2720  O avanço das tecnologias para estudos genômico...
# 2721  Projeto de PD&I para desenvolvimento de um sis...
# 2722  A Klabin S/A é uma empresa brasileira, de cará...
# 2723  Com a execução do presente projeto espera-se d...
# 2724  Desenvolvimento de Plataforma Digital de Bioin...
#
# [2725 rows x 2 columns]

# %% [markdown]
# ### Selecionar um texto específico para processamento (segunda linha, segunda coluna)

# %%
texto = df.iloc[1, 1]
texto
# Out:
# 'O uso de inovações tecnológicas auxilia as indústrias a desenvolverem modelos sustentáveis de produção, destaca-se a necessidade de pesquisas com o objetivo de desenvolver produto inovador pronto para consumo, agregação de valor e diferenciação de sabores, em especial produtos oriundos das florestas brasileiras que contribuem para o desenvolvimento da bioeconomia no Brasil.  Esse estudo também se propõe a avaliar as características do novo produto para fins de informação nutricional da rotulagem e acompanhar o período de vida útil do produto. A empresa está em busca de apoio na inovação e melhoria dos processos para desenvolver uma linha de produção sustentável com o uso de castanhas brasileiras, devido a grande diversidade dessas castanhas com alto valor nutricional e com sabor, aroma e alto nível de aceitação ampliando a diversificação de produtos.'

# %% [markdown]
# ### Importar bibliotecas do NLTK para processamento de linguagem natural

# %%
import nltk
from nltk.corpus import stopwords
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import RSLPStemmer

# %% [markdown]
# ### Criar diretório para armazenar os recursos do NLTK e adicionar ao caminho

# %%
# Criar um diretório específico para armazenar os recursos do nltk
nltk_data_dir = '/kaggle/working/nltk_data'
if not os.path.exists(nltk_data_dir):
    os.makedirs(nltk_data_dir)

# Adicionar o diretório ao caminho de busca do nltk
nltk.data.path.append(nltk_data_dir)

# %%
import nltk
print(nltk.data.path)
# Out:
# ['/root/nltk_data', '/usr/share/nltk_data', '/usr/local/share/nltk_data', '/usr/lib/nltk_data', '/usr/local/lib/nltk_data', '/kaggle/working/nltk_data']

# %% [markdown]
# ### Baixar recursos necessários do NLTK (lematização, tokenização, stopwords, etc.)

# %%
# Baixar recursos necessários
nltk.download('wordnet', download_dir=nltk_data_dir)
nltk.download('omw-1.4', download_dir=nltk_data_dir)  # Suporte multilíngue
nltk.download('punkt', download_dir=nltk_data_dir)  # Para tokenização
nltk.download('stopwords', download_dir=nltk_data_dir)  # Para stopwords
nltk.download('rslp', download_dir=nltk_data_dir)  # Stemmer para português
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data] Downloading package punkt to /kaggle/working/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package rslp to /kaggle/working/nltk_data...
# [nltk_data]   Unzipping stemmers/rslp.zip.
# True

# %% [markdown]
# ### Verificar os arquivos baixados

# %%
# Verifique os arquivos baixados
# !ls /kaggle/working/nltk_data/corpora
# Out:
# omw-1.4.zip  stopwords	stopwords.zip  wordnet.zip

# %% [markdown]
# ### Extrair arquivos zipados do NLTK (lematização e suporte multilíngue)

# %%
import zipfile
import os

# Caminho para o arquivo baixado
wordnet_zip_path = '/kaggle/working/nltk_data/corpora/wordnet.zip'
extract_path = '/kaggle/working/nltk_data/corpora/'

omw_zip_path = '/kaggle/working/nltk_data/corpora/omw-1.4.zip'
omw_extract_path = '/kaggle/working/nltk_data/omw-1.4/'

# Extraindo o conteúdo do arquivo zip
with zipfile.ZipFile(wordnet_zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# Extraindo o conteúdo do arquivo zip
with zipfile.ZipFile(omw_zip_path, 'r') as zip_ref:
    zip_ref.extractall(omw_extract_path)

# %% [markdown]
# ### Verificar se os arquivos foram extraídos corretamente

# %%
# Verifique se os arquivos foram extraídos corretamente
# !ls /kaggle/working/nltk_data/corpora/wordnet
# Out:
# LICENSE  adv.exc       data.adj   data.verb  index.noun   lexnames
# README	 citation.bib  data.adv   index.adj  index.sense  noun.exc
# adj.exc  cntlist.rev   data.noun  index.adv  index.verb   verb.exc

# %% [markdown]
# ### Carregar as stopwords em português e exibir a quantidade total

# %%
# Carregar stopwords em português
stopwords_nltk = set(stopwords.words('portuguese'))

# Exibir as stopwords em português
print(stopwords_nltk)
print(f"Total de Stopwords: {len(stopwords_nltk)}")
# Out:
# {'ser', 'tivessem', 'as', 'seríamos', 'como', 'vos', 'houvera', 'nossa', 'houverei', 'uma', 'pelas', 'você', 'haver', 'foi', 'era', 'estavam', 'meu', 'houveria', 'tem', 'e', 'fomos', 'for', 'houvéssemos', 'lhe', 'tiverem', 'deles', 'seja', 'dele', 'está', 'por', 'terá', 'tinham', 'estão', 'estes', 'forem', 'suas', 'um', 'essa', 'com', 'delas', 'seus', 'estivessem', 'em', 'houvemos', 'eles', 'quem', 'estávamos', 'esteve', 'que', 'esse', 'também', 'fosse', 'tenho', 'nos', 'houverem', 'mais', 'nosso', 'houvermos', 'de', 'tém', 'houverão', 'serão', 'os', 'à', 'o', 'serei', 'houvessem', 'aqueles', 'às', 'hajamos', 'tuas', 'são', 'ao', 'fora', 'pela', 'tenhamos', 'aquela', 'eu', 'tínhamos', 'tivéramos', 'estivesse', 'mas', 'estas', 'terão', 'seria', 'estou', 'numa', 'teria', 'hão', 'dos', 'aquilo', 'seu', 'teus', 'houveremos', 'depois', 'sejam', 'sem', 'formos', 'estivemos', 'nós', 'meus', 'do', 'isso', 'somos', 'houveram', 'temos', 'tivesse', 'aos', 'ela', 'seremos', 'vocês', 'estiver', 'tenham', 'elas', 'esteja', 'tiver', 'lhes', 'tivéssemos', 'já', 'há', 'teríamos', 'ele', 'haja', 'estamos', 'isto', 'fossem', 'ou', 'fui', 'estava', 'aquele', 'qual', 'sejamos', 'fôramos', 'na', 'houveriam', 'nossas', 'tenha', 'estejamos', 'estivéssemos', 'hajam', 'estivermos', 'seriam', 'hei', 'teu', 'teve', 'das', 'éramos', 'não', 'para', 'houvéramos', 'se', 'tiveram', 'estivéramos', 'até', 'esta', 'num', 'houvesse', 'dela', 'sua', 'terei', 'houve', 'a', 'teriam', 'tua', 'estiverem', 'tu', 'da', 'pelos', 'entre', 'é', 'nas', 'eram', 'minhas', 'houver', 'mesmo', 'nem', 'nossos', 'será', 'tivermos', 'houveríamos', 'teremos', 'fôssemos', 'estive', 'te', 'essas', 'tinha', 'me', 'tivera', 'estar', 'tivemos', 'esses', 'este', 'minha', 'no', 'só', 'tive', 'estiveram', 'pelo', 'estivera', 'havemos', 'muito', 'estejam', 'quando', 'sou', 'aquelas', 'foram', 'houverá'}
# Total de Stopwords: 207

# %% [markdown]
# ### Função para normalização do texto (minúsculas, remoção de stopwords e lematização)

# %% [markdown]
# ### Aplicar a função de normalização no texto

# %%
import string

# %%
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('portuguese'))
pontuacoes = string.punctuation

def normalizar_texto(texto):
    # Converter o texto para minúsculas
    texto = texto.lower()

    # Remover pontuação
    texto = ''.join([char for char in texto if char not in pontuacoes])

    # Tokenizar o texto
    tokens = word_tokenize(texto)

    # Remover stopwords e lematizar
    tokens_normalizados = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]

    return tokens_normalizados

texto_normalizado = normalizar_texto(texto)

print("Texto original:", texto)
print("Texto normalizado:", texto_normalizado)
# Out:
# Texto original: O uso de inovações tecnológicas auxilia as indústrias a desenvolverem modelos sustentáveis de produção, destaca-se a necessidade de pesquisas com o objetivo de desenvolver produto inovador pronto para consumo, agregação de valor e diferenciação de sabores, em especial produtos oriundos das florestas brasileiras que contribuem para o desenvolvimento da bioeconomia no Brasil.  Esse estudo também se propõe a avaliar as características do novo produto para fins de informação nutricional da rotulagem e acompanhar o período de vida útil do produto. A empresa está em busca de apoio na inovação e melhoria dos processos para desenvolver uma linha de produção sustentável com o uso de castanhas brasileiras, devido a grande diversidade dessas castanhas com alto valor nutricional e com sabor, aroma e alto nível de aceitação ampliando a diversificação de produtos.
# Texto normalizado: ['uso', 'inovações', 'tecnológicas', 'auxilia', 'indústrias', 'desenvolverem', 'modelos', 'sustentáveis', 'produção', 'destacase', 'necessidade', 'pesquisas', 'objetivo', 'desenvolver', 'produto', 'inovador', 'pronto', 'consumo', 'agregação', 'valor', 'diferenciação', 'sabores', 'especial', 'produtos', 'oriundos', 'florestas', 'brasileiras', 'contribuem', 'desenvolvimento', 'bioeconomia', 'brasil', 'estudo', 'propõe', 'avaliar', 'características', 'novo', 'produto', 'fin', 'informação', 'nutricional', 'rotulagem', 'acompanhar', 'período', 'vida', 'útil', 'produto', 'empresa', 'busca', 'apoio', 'inovação', 'melhoria', 'processos', 'desenvolver', 'linha', 'produção', 'sustentável', 'uso', 'castanhas', 'brasileiras', 'devido', 'grande', 'diversidade', 'dessas', 'castanhas', 'alto', 'valor', 'nutricional', 'sabor', 'aroma', 'alto', 'nível', 'aceitação', 'ampliando', 'diversificação', 'produtos']

# %% [markdown]
# ### Aplicar stemização com o RSLPStemmer no texto (remoção de stopwords)

# %%
# Inicializar o stemmer para português
stemmer = RSLPStemmer()

# Stopwords em português
stop_words = set(stopwords.words('portuguese'))

# Tokenizar o texto
tokens = word_tokenize(texto)

# Aplicar stemização, ignorando stopwords
tokens_stemmizados = [stemmer.stem(token) for token in tokens if token not in stop_words]

print("Texto original:", texto)
print("Texto stemmizado:", tokens_stemmizados)
# Out:
# Texto original: O uso de inovações tecnológicas auxilia as indústrias a desenvolverem modelos sustentáveis de produção, destaca-se a necessidade de pesquisas com o objetivo de desenvolver produto inovador pronto para consumo, agregação de valor e diferenciação de sabores, em especial produtos oriundos das florestas brasileiras que contribuem para o desenvolvimento da bioeconomia no Brasil.  Esse estudo também se propõe a avaliar as características do novo produto para fins de informação nutricional da rotulagem e acompanhar o período de vida útil do produto. A empresa está em busca de apoio na inovação e melhoria dos processos para desenvolver uma linha de produção sustentável com o uso de castanhas brasileiras, devido a grande diversidade dessas castanhas com alto valor nutricional e com sabor, aroma e alto nível de aceitação ampliando a diversificação de produtos.
# Texto stemmizado: ['o', 'uso', 'inov', 'tecnológ', 'auxil', 'indústr', 'desenvolv', 'model', 'sustent', 'produç', ',', 'destaca-s', 'necess', 'pesquis', 'obje', 'desenvolv', 'produt', 'inov', 'pront', 'consum', ',', 'agreg', 'val', 'diferenci', 'sab', ',', 'espec', 'produt', 'oriund', 'florest', 'brasil', 'contribu', 'desenvolv', 'bioeconom', 'brasil', '.', 'ess', 'estud', 'propõ', 'avali', 'caracterís', 'nov', 'produt', 'fim', 'inform', 'nutric', 'rotul', 'acompanh', 'períod', 'vid', 'útil', 'produt', '.', 'a', 'empr', 'busc', 'apoi', 'inov', 'melh', 'process', 'desenvolv', 'linh', 'produç', 'sustent', 'uso', 'castanh', 'brasil', ',', 'dev', 'grand', 'divers', 'dess', 'castanh', 'alt', 'val', 'nutric', 'sab', ',', 'arom', 'alt', 'nível', 'aceit', 'ampli', 'diversific', 'produt', '.']

# %% [markdown]
# ### Carregar o modelo de português do SpaCy e exibir stopwords

# %%
# !python -m spacy download pt_core_news_md
# Out:
# Collecting pt-core-news-md==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_md-3.7.0/pt_core_news_md-3.7.0-py3-none-any.whl (42.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 22.0 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from pt-core-news-md==3.7.0) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.9.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.4)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-md==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-md
# Successfully installed pt-core-news-md-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_md')

# %%
import spacy

# Carregar o modelo de português do SpaCy
nlp = spacy.load("pt_core_news_md")

# Acessar a lista de stopwords
stopwords_spacy = nlp.Defaults.stop_words

# Exibir algumas stopwords
print(f"Total de Stopwords: {len(stopwords_spacy)}")
print(f"Algumas Stopwords: {list(stopwords_spacy)[:10]}")
# Out:
# Total de Stopwords: 416
# Algumas Stopwords: ['fostes', 'sobre', 'terceira', 'conhecida', 'zero', 'assim', 'meu', 'maiorias', 'sei', 'próxima']

# %%
print(df.columns)
# Out:
# Index(['Título_Público', 'Descricao_pública'], dtype='object')

# %% [markdown]
# ### Pré-processar a coluna de texto 'Descricao_pública' no DataFrame

# %%
# Converter todos os valores para string e tratar valores nulos
df['Descricao_pública'] = df['Descricao_pública'].fillna('').astype(str)

# %%
# Tokenizar e normalizar os textos
textos_normalizados = [' '.join(normalizar_texto(texto)) for texto in df['Descricao_pública']]

# %%
# Converter valores para strings e tratar NaN
df['Descricao_pública'] = df['Descricao_pública'].fillna('').astype(str)

# Normalizar os textos
textos_normalizados = [' '.join(normalizar_texto(texto)) for texto in df['Descricao_pública']]

# Aplicar TF-IDF
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(textos_normalizados)

# Aplicar KMeans para clusterização
from sklearn.cluster import KMeans

# Definir o número de clusters
num_clusters = 5
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(X)

# Adicionar os rótulos dos clusters ao DataFrame
df['Cluster'] = kmeans.labels_

# Visualizar os clusters
print(df[['Título_Público', 'Descricao_pública', 'Cluster']].head())
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#                                       Título_Público  \
# 0  Açúcar de frutas e aplicação em bolos como sub...
# 1  Desenvolver uma linha de farofas com castanhas...
# 2  Desenvolvimento de cobertura líquida para sorvete
# 3       Desenvolvimento de conserva de tomate cereja
# 4  Desenvolvimento de massa alimentícia enriqueci...
#
#                                    Descricao_pública  Cluster
# 0  O uso de inovações tecnológicas auxilia as ind...        3
# 1  O uso de inovações tecnológicas auxilia as ind...        3
# 2  O Brasil é considerado um país com a maior bio...        3
# 3  O Brasil é considerado o país com maior biodiv...        3
# 4  Nos últimos anos a comunidade científica tem d...        3

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# Reduzindo a dimensionalidade para 2 componentes principais
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())

# Plotando os clusters
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans.labels_, cmap='rainbow')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('Visualização dos Clusters com PCA')
plt.show()

# %%
# !python -m spacy download pt_core_news_sm
# Out:
# Collecting pt-core-news-sm==3.7.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.7.0/pt_core_news_sm-3.7.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 93.9 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: spacy<3.8.0,>=3.7.0 in /opt/conda/lib/python3.10/site-packages (from pt-core-news-sm==3.7.0) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.9.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (70.0.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (21.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in /opt/conda/lib/python3.10/site-packages (from spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /opt/conda/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/conda/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.7.10)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.4)
# Requirement already satisfied: click>=8.0.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /opt/conda/lib/python3.10/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /opt/conda/lib/python3.10/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (2.18.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.10/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.0->pt-core-news-sm==3.7.0) (0.1.2)
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.7.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')

# %%
import spacy

# Carregar o modelo em português
nlp = spacy.load('pt_core_news_sm')

# %%
def processar_texto(texto):
    doc = nlp(texto)
    # Pegar apenas os substantivos e adjetivos lematizados
    palavras_importantes = [token.lemma_ for token in doc if token.pos_ in ['NOUN', 'ADJ']]
    return ' '.join(palavras_importantes)

# Aplicar a função em cada texto da coluna 'Descricao_pública'
df['Descricao_processada'] = df['Descricao_pública'].apply(processar_texto)

# %% [markdown]
# ### Aplicar TF-IDF para conversão de texto em vetores

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['Descricao_processada'])

# %% [markdown]
# ### Aplicar KMeans para clusterização dos textos

# %%
from sklearn.cluster import KMeans

# Escolha o número de clusters que faz sentido para seu problema
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)

# Adicionar os clusters ao dataframe
df['Cluster'] = kmeans.labels_
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
print(df[['Título_Público', 'Descricao_processada', 'Cluster']].head())
# Out:
#                                       Título_Público  \
# 0  Açúcar de frutas e aplicação em bolos como sub...
# 1  Desenvolver uma linha de farofas com castanhas...
# 2  Desenvolvimento de cobertura líquida para sorvete
# 3       Desenvolvimento de conserva de tomate cereja
# 4  Desenvolvimento de massa alimentícia enriqueci...
#
#                                 Descricao_processada  Cluster
# 0  uso inovação tecnológico indústria modelo sust...        2
# 1  uso inovação tecnológico indústria modelo sust...        2
# 2  país grande biodiversidade mundo espécie bioma...        2
# 3  país grande biodiversidade mundo espécie bioma...        4
# 4  último ano comunidade científico interesse ela...        4

# %% [markdown]
# ### Aplicar T-SNE para uma visualização mais clara dos clusters

# %%
from sklearn.manifold import TSNE

# Reduzir as dimensões com PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X.toarray())  # 'X' é o resultado do TF-IDF

# Usando T-SNE para uma redução dimensional mais clara
tsne = TSNE(n_components=2, perplexity=30, n_iter=300)
X_tsne = tsne.fit_transform(X.toarray())

# Criar um gráfico dos clusters usando T-SNE
plt.figure(figsize=(10, 7))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=df['Cluster'], cmap='viridis')
plt.colorbar()
plt.title('Visualização dos Clusters com T-SNE')
plt.xlabel('Componente 1')
plt.ylabel('Componente 2')
plt.show()
